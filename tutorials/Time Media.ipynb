# %%
import sys
sys.path.insert(0, '../')

# %% [markdown]
# # Time Media

# %%
from yuntu import Audio

# %%
SAMPLE_AUDIO = '/Users/erobredo/Downloads/11k16bitpcm.wav'
audio = Audio(path=SAMPLE_AUDIO)

# %%
audio
# Out:
# Audio(path='/Users/erobredo/Downloads/11k16bitpcm.wav', duration=13.811065759637188, samplerate=11025)

# %%
cut = audio.cut(start_time=10, end_time=15, pad=True, constant_values=0)

# %%
cut.plot()
